# %%
#1. Write a Python program to create a tuple.

t1=(1,2,3)
t1
# Out:
# (1, 2, 3)

# %%
#2. Write a Python program to create a tuple with different data types.

t2=("ghgh")
t2
# Out:
# 'ghgh'

# %%
# 3. Write a Python program to create a tuple of numbers and print one item.

t3=(34,"jk",[2,3.4],{1,5,7},{'a':23},{'b':34})
t3
# Out:
# (34, 'jk', [2, 3.4], {1, 5, 7}, {'a': 23}, {'b': 34})

# %%
t1=1,2,3

# %%
# 4. Write a Python program to unpack a tuple into several variables.
tuple1 = (11, 22, 33, 44)
v1, v2, v3, v4 = tuple1
print("Unpacked variables are: ")
print("v1= ",v1)
print("v2= ",v2)
print("v3= ",v3)
print("v4= ",v4)
# Out:
# Unpacked variables are:
# v1=  11
# v2=  22
# v3=  33
# v4=  44

# %%
#5. Write a Python program to add an item to a tuple.

t1=(5,7,8)
new_item = 45
tuple1 = t1 + (new_item,)
tuple1
# Out:
# (5, 7, 8, 45)

# %%
#6. Write a Python program to convert a tuple to a string.

t1=(2,3,4)
str((2,3,4))
# Out:
# '(2, 3, 4)'

# %%
#7. Write a Python program to get the 4th element from the last element of a tuple.

t2=('I','A','C','S','D')
t1=t2[-4]
print(t1)
# Out:
# A

# %%
t1=(2,3,4,)
s1=""
for e1 in t1:
    s1+=str(e1)
print(s1)
# Out:
# 234

# %%
#8. Write a Python program to create the colon of a tuple.


t1=(4,5,6,(7,8,9))

# %%
#9. Write a Python program to find repeated items in a tuple.

t1=(9,9,9,9,23,45,67,67,10)
t1.count(9)
# Out:
# 4

# %%
#9. Write a Python program to find repeated items in a tuple.

for e1 in set(t1):
  if t1.count(e1) > 1:
        print("Repeated Elements: ",e1)
# Out:
# Repeated Elements:  67
# Repeated Elements:  9

# %%
repeated_set = set()
for idx1 in range (len(t1)):
    for idx2 in range (len(t1)):
        if(idx1 != idx2) and (t1[idx1] == t1[idx2]) and (t1[idx1] not in repeated_set):
            repeated_set.add(t1[idx1])
print(repeated_set)
# Out:
# {11, 44, 22}

# %%
t1 = (11,22,11,66,55,33,44,55,66)
repeated_items = {e for e in t1 if t1.count(e)>1}
if repeated_items:
  print("Repeated items are: ",repeated_items)
else:
  print("Repeated items are not present")
# Out:
# Repeated items are:  {66, 11, 55}

# %%
# 10. Write a Python program to check whether an element exists within a tuple.

t1 = (11,22,33,44,55)
e = 22
if e in t1:
  print("Number is present")
else:
  print("Number is not present")
# Out:
# Number is present

# %%
# 11. Write a Python program to convert a list to a tuple.
list([2,3,4])
t1
# Out:
# (2, 3, 4)

# %%
# 12. Write a Python program to remove an item from a tuple.
t1 = (11,22,33,44,55)
item_remove = 33
list1 = list(t1)
if item_remove in list1:
  list1.remove(item_remove)
tuple1 = tuple(list1)
tuple1
# Out:
# (11, 22, 44, 55)

# %%
# 13. Write a Python program to slice a tuple.

t1 = (3,5,6,4,7,8,4,2,1)
t1[1:5]
# Out:
# (5, 6, 4, 7)

# %%
# 15. Write a Python program to find the length of a tuple.

tuple1 = (11,22,33,44,55,66)
length = len(tuple1)
print("Length of tuple : ",length)
# Out:
# Length of tuple :  6

# %%
# 16. Write a Python program to convert a tuple to a dictionary

t1 = (("a", 1), ("b", 2), ("c", 3))
dict1 = dict(t1)
dict1
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# 17. Write a Python program to unzip a list of tuples into individual lists.
t1 = [("a", 1), ("b", 2), ("c", 3)]
unzipped = list(zip(t1))
print("Unzipped list: ")
for list1 in unzipped:
  print(list1)
# Out:
# Unzipped list:
# (('a', 1),)
# (('b', 2),)
# (('c', 3),)

# %%
# 18. Write a Python program to reverse a tuple.

t1 = (1,2,3,4)
print(t1[::-1], tuple(reversed(t1)))
# Out:
# (4, 3, 2, 1) (4, 3, 2, 1)

# %%
# 19. Write a Python program to convert a list of tuples into a dictionary.


list_t = [(1,2),(4,5)]
dict(list_t)
# Out:
# {1: 2, 4: 5}

# %%
# 20.Write a Python program to print a tuple with string formatting.
# Sample tuple : (100, 200, 300)
# Output : This is a tuple (100, 200, 300)

t1=(100,200,300)
print("This is a tuple",str(t1))
# Out:
# This is a tuple (100, 200, 300)

# %%
# 21.Write a Python program to replace the last value of tuples in a list.
# Sample list: [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
# Expected Output: [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

sample_list = [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
l1=[]
for i in sample_list:
    l1.append(tuple((*i[:2],100)))
l1
# Out:
# [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
# 22. Write a Python program to remove an empty tuple(s) from a list of tuples.
# Sample data: [(), (), ('',), ('a', 'b'), ('a', 'b', 'c'), ('d')]
# Expected output: [('',), ('a', 'b'), ('a', 'b', 'c'), 'd']

data = [(), (), ('',), ('a', 'b'), ('a', 'b', 'c'), ('d')]
filtered_data = [tup for tup in data if tup]
print(filtered_data)

#tuple((*t[:2],4))
# Out:
# [('',), ('a', 'b'), ('a', 'b', 'c'), 'd']

# %%
# 23. Write a Python program to sort a tuple by its float element.
# Sample data: [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
# Expected Output: [('item3', '24.5'), ('item2', '15.10'), ('item1', '12.20')]

sample_list=[('item', '12.20'),('item2','15.10'),('item3','24.5')]
list1=[t[1] for t in sample_list]
list1.sort(reverse=True)
print(list1)
list2=[()]*len(sample_list)
for tup in list:
    idx = list1.index(tup[1])
    list2[idx]=tup
    print(list2)
# Out:
# ['24.5', '15.10', '12.20']
# [(), (), ('item', '12.20')]
# [(), ('item2', '15.10'), ('item', '12.20')]
# [('item3', '24.5'), ('item2', '15.10'), ('item', '12.20')]

# %%
#24. Write a Python program to count the elements in a list until an element is a tuple.

list1 = [1,2,(3,4),5,6]
count = 0

for e in list1:
  if isinstance(1,tuple):
    break
  count+=1
print("Number of elements in list until an element is tuple: ",count)
# Out:
# Number of elements in list until an element is tuple:  5

# %%
# 25. Write a Python program to convert a given string list to a tuple.
# Original string: python 3.0
# <class 'str'>
# Convert the said string to a tuple:
# ('p', 'y', 't', 'h', 'o', 'n', '3', '.', '0')
# <class 'tuple'>

string1 = "python 3.0"
#list1 = list(string1)
#tuple1 = tuple(list1)
tuple1 = tuple(string1)
tuple1
# Out:
# ('p', 'y', 't', 'h', 'o', 'n', ' ', '3', '.', '0')

# %%
# 26. Write a Python program to calculate the product, multiplying all ti    he numbers in a given tuple.
# Original Tuple:
# (4, 3, 2, 2, -1, 18)
# Product - multiplying all the numbers of the said tuple: -864
# Original Tuple:
# (2, 4, 8, 8, 3, 2, 9)
# Product - multiplying all the numbers of the said tuple: 27648

tuple1 = (4,3,2,2,-1,18)
product = 1
for num in tuple1:
  product *= num
print("Original tuple: ",tuple1)
print("Product - multiplying all the numbers of the said tuple: ",product)

tuple2 = (2,4,8,8,3,2,9)
product = 1
for num in tuple2:
  product *= num
print("Original tuple: ",tuple2)
print("Product - multiplying all the numbers of the said tuple: ",product)
# Out:
# Original tuple:  (4, 3, 2, 2, -1, 18)
# Product - multiplying all the numbers of the said tuple:  -864
# Original tuple:  (2, 4, 8, 8, 3, 2, 9)
# Product - multiplying all the numbers of the said tuple:  27648

# %%
# 27. Write a Python program to calculate the average value of the numbers in a given tuple of tuples.
# Original Tuple:
# ((10, 10, 10, 12), (30, 45, 56, 45), (81, 80, 39, 32), (1, 2, 3, 4))
# Average value of the numbers of the said tuple of tuples:
# [30.5, 34.25, 27.0, 23.25]
# Original Tuple:
# ((1, 1, -5), (30, -15, 56), (81, -60, -39), (-10, 2, 3))
# Average value of the numbers of the said tuple of tuples:
# [25.5, -18.0, 3.75]

tuple1 = ((10, 10, 10, 12), (30, 45, 56, 45), (81, 80, 39, 32), (1, 2, 3, 4))
sums = [sum(x) for x in zip(*tuple1)]
avg = [x/len(tuple1) for x in sums]
print("Average value of the numbers of the said tuple of tuples: ")
print(avg)

tuple2 = ((1, 1, -5), (30, -15, 56), (81, -60, -39), (-10, 2, 3))
sum1 = [sum(x) for x in zip(*tuple2)]
avg1 =  [x/len(tuple2) for x in sum1]
print("Average value of the numbers of the said tuple of tuples: ")
print(avg1)
# Out:
# Average value of the numbers of the said tuple of tuples:
# [30.5, 34.25, 27.0, 23.25]
# Average value of the numbers of the said tuple of tuples:
# [25.5, -18.0, 3.75]

# %%
# 28. Write a Python program to convert a tuple of string values to a tuple of integer values.
# Original tuple values:
# (('333', '33'), ('1416', '55'))
# New tuple values:
# ((333, 33), (1416, 55))

tuple1 = (('333','33'),('1416','55'))
new_tuple = tuple((int(x),int(y)) for x,y in tuple1)
print("New tuple values:")
print(new_tuple)
# Out:
# New tuple values:
# ((333, 33), (1416, 55))

# %%
# 29. Write a Python program to convert a given tuple of positive integers into an integer.
# Original tuple:
# (1, 2, 3)
# Convert the said tuple of positive integers into an integer:
# 123
# Original tuple:
# (10, 20, 40, 5, 70)
# Convert the said tuple of positive integers into an integer:
# 102040570

tuple1 = (1,2,3)
result = 0
for num in tuple1:
  result = result * 10 + num
print(result)

tuple2 = (10, 20, 40, 5, 70)
result2 = int(''.join(map(str,tuple2)))
print(result2)
# Out:
# 123
# 102040570

# %%
# 30. Write a Python program to check if a specified element appears in a tuple of tuples.
# Original list:
# (('Red', 'White', 'Blue'), ('Green', 'Pink', 'Purple'), ('Orange', 'Yellow', 'Lime'))
# Check if White present in said tuple of tuples!
# True
# Check if White present in said tuple of tuples!
# True
# Check if Olive present in said tuple of tuples!
# False

tuple1 = (('Red', 'White', 'Blue'), ('Green', 'Pink', 'Purple'), ('Orange', 'Yellow', 'Lime'))
e = 'White'
print(any(e in tup for tup in tuple1))

e= 'Olive'
print(any(e in tup for tup in tuple1))

# e = 'White'
# for tup in tuple1:
#   if e in tup:
#     is_present = True
#     break
# print("Check if",e,"present")
# print(is_present)
# Out:
# True
# False

# %%
# 31. Write a Python program to compute the element-wise sum of given tuples.
# Original lists:
# (1, 2, 3, 4)
# (3, 5, 2, 1)
# (2, 2, 3, 1)
# Element-wise sum of the said tuples:
# (6, 9, 8, 6)

tuple1 = (1,2,3,4)
tuple2 = (3,5,2,1)
tuple3 = (2,2,3,1)
result = tuple(sum(x) for x in zip(tuple1,tuple2,tuple3))
print("Element-wise sum of tuples: ")
print(result)
# Out:
# Element-wise sum of tuples:
# (6, 9, 8, 6)

# %%
# 32. Write a Python program to compute the sum of all the elements of each tuple stored inside a list of tuples.
# Original list of tuples:
# [(1, 2), (2, 3), (3, 4)]
# Sum of all the elements of each tuple stored inside the said list of tuples:
# [3, 5, 7]
# Original list of tuples:
# [(1, 2, 6), (2, 3, -6), (3, 4), (2, 2, 2, 2)]
# Sum of all the elements of each tuple stored inside the said list of tuples:
# [9, -1, 7, 8

tuple1 = [(1,2),(2,3),(3,4)]
sum1 = [sum(x) for x in tuple1]
print("Sum of all elements of each tuple: ")
print(sum1)

tuple2 = [(1, 2, 6), (2, 3, -6), (3, 4), (2, 2, 2, 2)]
sum2 = [sum(y) for y in tuple2]
print("Sum of all elements of each tuple: ")
sum2
# Out:
# Sum of all elements of each tuple:
# [3, 5, 7]
# Sum of all elements of each tuple:
# [9, -1, 7, 8]

# %%
# 33. Write a Python program to convert a given list of tuples to a list of lists.
# Original list of tuples: [(1, 2), (2, 3), (3, 4)]
# Convert the said list of tuples to a list of lists: [[1, 2], [2, 3], [3, 4]]
# Original list of tuples: [(1, 2), (2, 3, 5), (3, 4), (2, 3, 4, 2)]
# Convert the said list of tuples to a list of lists: [[1, 2], [2, 3, 5], [3, 4], [2, 3, 4, 2]]

list_of_tuple1 = [(1, 2), (2, 3), (3, 4)]
list_of_list1 = [list(tup) for tup in list_of_tuple1]
print("Convert list of tuples to list of lists: ")
print(list_of_list1)

list_of_tuple2 = [(1, 2), (2, 3), (3, 4)]
list_of_list2 = [list(tup) for tup in list_of_tuple2]
print("Convert list of tuples to list of lists: ")
print(list_of_list2)
# Out:
# Convert list of tuples to list of lists:
# [[1, 2], [2, 3], [3, 4]]
# Convert list of tuples to list of lists:
# [[1, 2], [2, 3], [3, 4]]
